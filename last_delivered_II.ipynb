# %% [markdown]
# <a href="https://colab.research.google.com/github/MohamedAhmedGalal/human-vs-machine-arabic-nlp/blob/main/last_delivered_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Explanation of `drive.mount('/content/drive')`
#
# ## Purpose:
# - The `drive.mount('/content/drive')` command allows you to connect your Google Drive to your Colab notebook.
# - This enables access to files stored in your Google Drive directly from the Colab environment.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install gdown
# !gdown https://drive.google.com/file/d/1Wf0J8e4MF7N5M6VcCpxTNIHKIgssaARx/view?usp=drive_link
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.12.14)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=1Wf0J8e4MF7N5M6VcCpxTNIHKIgssaARx
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/1Wf0J8e4MF7N5M6VcCpxTNIHKIgssaARx/view?usp=drive_link
# To: /content/view?usp=drive_link
# 92.4kB [00:00, 2.12MB/s]

# %% [markdown]
# !cp -r /content/drive/MyDrive/Human_Articles_VS_Machine_Generated_Articles_Detection_datasetV2.zip
#
# ## Purpose:
# - The command copies the specified file or directory from Google Drive to the current working directory in Colab.
# - It uses the `cp` command to copy files and folders.

# %%
# !gdown --id 1Wf0J8e4MF7N5M6VcCpxTNIHKIgssaARx

# !cp -r /content/Copy\ of\ Human_Articles_VS_Machine_Generated_Articles_Detection_datasetV2.zip /content/
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1Wf0J8e4MF7N5M6VcCpxTNIHKIgssaARx
# From (redirected): https://drive.google.com/uc?id=1Wf0J8e4MF7N5M6VcCpxTNIHKIgssaARx&confirm=t&uuid=7c96d181-75d5-4c31-ae92-15697cd8de9d
# To: /content/Copy of Human_Articles_VS_Machine_Generated_Articles_Detection_datasetV2.zip
# 100% 35.7M/35.7M [00:01<00:00, 22.7MB/s]
# cp: '/content/Copy of Human_Articles_VS_Machine_Generated_Articles_Detection_datasetV2.zip' and '/content/Copy of Human_Articles_VS_Machine_Generated_Articles_Detection_datasetV2.zip' are the same file

# %%
# %%capture
# !unzip /content/Copy\ of\ Human_Articles_VS_Machine_Generated_Articles_Detection_datasetV2.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/articles/real/YEM_Almasdar/YEM_Almasdar_article_83.txt
#   inflating: dataset/articles/real/YEM_Almasdar/YEM_Almasdar_article_121.txt
#   inflating: dataset/articles/real/YEM_Almasdar/YEM_Almasdar_article_156.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_215_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_43_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_198_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_102_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_31_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_232_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_208_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_79_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_254_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_26_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_131_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_110_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_63_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_202_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_28_summary.txt
#  extracting: dataset/summaries/MUR_sahra/MUR_sahra_article_107_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_56_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_12_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_93_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_68_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_39_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_36_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_142_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_124_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_87_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_19_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_78_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_135_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_162_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_122_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_245_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_194_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_170_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_230_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_141_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_7_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_168_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_221_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_175_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_106_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_5_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_109_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_18_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_196_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_3_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_27_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_82_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_117_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_41_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_177_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_76_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_161_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_253_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_45_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_227_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_256_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_89_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_179_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_139_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_172_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_22_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_164_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_152_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_130_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_9_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_220_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_60_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_15_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_176_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_138_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_214_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_183_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_16_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_239_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_165_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_77_summary.txt
#  extracting: dataset/summaries/MUR_sahra/MUR_sahra_article_57_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_199_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_259_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_29_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_38_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_113_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_14_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_67_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_6_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_201_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_147_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_119_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_71_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_191_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_64_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_33_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_200_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_112_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_114_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_233_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_244_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_129_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_248_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_121_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_148_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_251_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_186_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_235_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_250_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_81_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_34_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_242_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_209_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_70_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_69_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_218_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_116_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_108_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_90_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_92_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_111_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_226_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_133_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_54_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_132_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_224_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_143_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_261_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_128_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_156_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_241_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_11_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_210_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_2_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_101_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_246_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_207_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_61_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_146_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_187_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_98_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_126_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_145_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_144_summary.txt
#  extracting: dataset/summaries/MUR_sahra/MUR_sahra_article_238_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_158_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_72_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_211_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_166_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_192_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_205_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_193_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_52_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_260_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_1_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_21_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_171_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_91_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_159_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_240_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_125_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_252_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_180_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_154_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_17_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_188_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_40_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_100_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_118_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_35_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_151_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_249_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_84_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_65_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_49_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_51_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_48_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_53_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_136_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_155_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_95_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_234_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_153_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_149_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_150_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_181_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_80_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_127_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_20_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_225_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_13_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_75_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_137_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_219_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_115_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_167_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_37_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_216_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_105_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_10_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_66_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_163_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_50_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_94_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_263_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_228_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_182_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_231_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_44_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_74_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_189_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_42_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_96_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_190_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_243_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_185_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_30_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_140_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_195_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_203_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_4_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_257_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_24_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_103_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_157_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_237_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_247_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_134_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_59_summary.txt
#  extracting: dataset/summaries/MUR_sahra/MUR_sahra_article_255_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_184_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_8_summary.txt
#  extracting: dataset/summaries/MUR_sahra/MUR_sahra_article_32_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_47_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_229_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_85_summary.txt
#  extracting: dataset/summaries/MUR_sahra/MUR_sahra_article_178_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_97_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_212_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_55_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_160_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_213_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_58_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_204_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_197_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_88_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_223_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_23_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_258_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_120_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_262_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_169_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_62_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_222_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_236_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_83_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_46_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_174_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_25_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_173_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_104_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_73_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_99_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_217_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_86_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_206_summary.txt
#   inflating: dataset/summaries/MUR_sahra/MUR_sahra_article_123_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_124_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_139_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_181_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_40_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_246_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_255_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_28_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_224_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_110_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_165_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_208_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_230_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_177_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_79_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_8_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_240_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_211_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_76_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_214_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_149_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_94_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_237_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_80_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_121_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_260_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_50_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_238_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_102_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_103_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_52_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_182_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_156_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_107_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_187_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_125_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_176_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_159_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_213_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_57_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_252_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_154_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_132_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_173_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_87_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_97_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_122_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_133_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_75_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_115_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_6_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_170_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_188_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_112_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_146_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_218_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_116_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_18_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_259_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_164_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_78_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_58_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_209_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_235_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_73_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_134_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_118_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_239_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_184_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_262_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_24_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_204_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_91_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_46_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_166_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_123_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_197_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_84_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_163_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_49_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_35_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_152_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_93_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_126_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_223_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_64_summary.txt
#  extracting: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_226_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_17_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_32_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_245_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_135_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_42_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_26_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_137_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_99_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_70_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_140_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_120_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_201_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_51_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_228_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_178_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_221_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_48_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_185_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_2_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_38_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_194_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_108_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_236_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_86_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_167_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_242_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_129_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_147_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_111_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_95_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_114_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_263_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_82_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_43_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_174_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_247_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_62_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_190_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_229_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_144_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_16_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_85_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_195_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_248_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_225_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_30_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_202_summary.txt
#  extracting: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_150_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_212_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_27_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_39_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_92_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_71_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_56_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_88_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_172_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_67_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_215_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_183_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_119_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_141_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_251_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_249_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_234_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_142_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_41_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_180_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_7_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_1_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_131_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_254_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_232_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_83_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_192_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_47_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_155_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_45_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_257_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_25_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_241_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_65_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_4_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_127_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_200_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_37_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_162_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_15_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_74_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_104_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_98_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_22_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_158_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_256_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_13_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_216_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_90_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_60_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_55_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_34_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_193_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_206_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_128_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_101_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_191_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_106_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_179_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_161_summary.txt
#  extracting: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_89_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_19_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_136_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_138_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_227_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_169_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_68_summary.txt
#  extracting: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_53_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_231_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_250_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_168_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_61_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_175_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_210_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_113_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_14_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_5_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_66_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_253_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_9_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_258_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_198_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_109_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_207_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_117_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_12_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_11_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_148_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_157_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_196_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_31_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_217_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_233_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_36_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_59_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_20_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_244_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_171_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_143_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_77_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_261_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_186_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_96_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_72_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_151_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_160_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_63_summary.txt
#  extracting: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_3_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_189_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_100_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_29_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_130_summary.txt
#  extracting: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_153_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_44_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_21_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_81_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_203_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_23_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_145_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_33_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_105_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_222_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_243_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_69_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_199_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_205_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_10_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_220_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_54_summary.txt
#   inflating: dataset/summaries/EGY_alyoomSabi/EGY_alyoomSabi_article_219_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_253_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_233_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_84_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_56_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_58_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_175_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_108_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_119_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_213_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_182_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_239_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_254_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_256_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_93_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_184_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_189_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_50_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_86_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_22_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_127_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_195_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_134_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_183_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_14_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_177_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_73_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_71_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_135_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_49_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_16_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_26_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_212_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_263_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_146_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_104_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_197_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_222_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_236_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_114_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_70_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_83_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_162_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_74_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_198_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_148_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_172_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_113_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_110_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_125_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_95_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_76_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_179_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_150_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_245_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_19_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_68_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_209_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_170_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_69_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_81_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_136_summary.txt
#   inflating: dataset/summaries/KUW_nahar/KUW_nahar_article_55_summary.txt
# ...
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_77_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_193_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_84_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_260_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_11_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_263_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_127_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_214_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_256_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_48_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_82_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_248_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_105_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_140_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_2_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_182_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_204_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_12_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_211_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_10_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_185_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_244_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_87_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_5_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_215_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_161_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_258_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_72_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_138_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_51_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_34_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_166_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_170_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_54_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_65_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_16_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_35_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_139_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_192_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_75_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_212_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_158_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_108_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_167_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_22_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_160_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_241_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_126_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_86_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_134_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_186_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_56_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_165_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_210_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_32_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_178_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_57_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_28_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_116_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_81_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_53_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_259_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_235_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_189_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_52_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_85_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_66_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_103_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_234_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_177_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_183_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_18_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_254_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_147_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_150_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_112_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_195_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_69_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_169_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_239_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_111_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_88_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_76_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_200_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_159_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_224_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_50_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_176_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_243_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_25_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_119_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_180_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_13_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_23_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_8_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_110_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_102_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_27_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_1_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_45_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_33_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_153_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_162_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_156_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_191_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_205_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_24_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_262_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_44_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_130_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_221_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_92_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_17_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_29_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_26_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_64_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_115_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_89_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_95_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_63_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_249_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_136_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_154_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_83_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_216_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_113_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_19_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_219_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_125_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_261_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_251_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_199_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_14_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_9_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_257_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_229_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_4_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_109_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_148_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_238_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_79_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_141_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_194_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_46_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_55_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_173_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_142_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_155_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_47_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_36_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_39_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_252_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_208_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_181_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_90_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_203_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_41_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_99_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_60_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_228_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_62_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_164_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_209_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_188_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_94_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_101_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_172_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_122_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_93_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_96_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_37_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_78_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_49_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_133_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_68_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_223_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_246_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_190_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_128_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_7_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_58_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_197_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_104_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_240_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_226_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_120_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_118_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_218_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_206_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_157_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_233_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_73_summary.txt
#   inflating: dataset/summaries/YEM_Almasdar/YEM_Almasdar_article_43_summary.txt

# %% [markdown]
# ## Purpose:
# - This command installs several Python libraries essential for natural language processing (NLP) tasks, particularly those involving Arabic text.
#
# ## Breakdown of Components:
#
# 1. **`%%capture`**:
#    - A magic command in Jupyter and Colab notebooks that captures the output of the cell, preventing it from displaying in the notebook.
#    - Useful for suppressing verbose installation logs.
#
# 2. **`!pip install`**:
#    - The `!` allows execution of shell commands within a notebook cell.
#    - `pip install` is the command to install Python packages.
#
# 3. **List of Packages**:
#    - **`transformers`**: A library by Hugging Face providing pre-trained models for NLP tasks.
#    - **`datasets`**: Offers a collection of ready-to-use datasets and tools for loading and processing them.
#    - **`arabic-reshaper`**: Reconstructs Arabic sentences for applications that don't support Arabic script. :contentReference[oaicite:0]{index=0}
#    - **`python-bidi`**: Implements the Unicode Bidirectional Algorithm necessary for displaying right-to-left languages like Arabic.
#    - **`wordcloud`**: Generates word clouds from text data.
#    - **`arabert`**: Provides pre-trained BERT models specifically for Arabic. :contentReference[oaicite:1]{index=1}
#    - **`pyarabic`**: A library for Arabic language processing, offering functions to manipulate Arabic text. :contentReference[oaicite:2]{index=2}
#    - **`tensorboard`**: A visualization tool for monitoring machine learning experiments.

# %%
# %%capture
# !pip install transformers datasets arabic-reshaper python-bidi wordcloud arabert pyarabic tensorboard
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.47.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (3.2.0)
# Requirement already satisfied: arabic-reshaper in /usr/local/lib/python3.10/dist-packages (3.0.0)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.10/dist-packages (0.6.3)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.4)
# Requirement already satisfied: arabert in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: pyarabic in /usr/local/lib/python3.10/dist-packages (0.6.15)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.27.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (11.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.8.0)
# Requirement already satisfied: farasapy in /usr/local/lib/python3.10/dist-packages (from arabert) (0.0.14)
# Requirement already satisfied: emoji==1.4.2 in /usr/local/lib/python3.10/dist-packages (from arabert) (1.4.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from pyarabic) (1.17.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (1.68.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.7)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (4.25.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (75.1.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard) (3.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.12.14)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)

# %% [markdown]
# # Explanation of Imported Libraries and Modules
#
# This section provides an overview of the libraries and modules imported in the code, highlighting their purposes and functionalities.
#
# ## Standard Libraries
#
# - **`os`**: Provides a way to interact with the operating system, enabling tasks like file and directory manipulation.
# - **`warnings`**: Offers a mechanism to control the display of warning messages.
# - **`re`**: Supports regular expression operations for pattern matching and string manipulation.
# - **`collections.Counter`**: A subclass of the dictionary object, useful for counting hashable objects.
#
# ## Data Manipulation and Analysis
#
# - **`pandas as pd`**: A powerful data manipulation and analysis library, providing data structures like DataFrames.
# - **`numpy as np`**: Supports large, multi-dimensional arrays and matrices, along with a collection of mathematical functions.
#
# ## Machine Learning and NLP
#
# - **`torch`**: The core library of PyTorch, an open-source machine learning framework.
# - **`datasets.Dataset`**: Part of the Hugging Face Datasets library, facilitating the handling of large datasets.
# - **`transformers`**: A library by Hugging Face that provides general-purpose architectures for natural language understanding and generation.
#   - **`AutoTokenizer`**: Automatically retrieves the appropriate tokenizer for a given model.
#   - **`AutoModelForSequenceClassification`**: Fetches a pre-trained model suitable for sequence classification tasks.
#   - **`TrainingArguments`**: Specifies hyperparameters for training models.
#   - **`Trainer`**: A class that simplifies the training and evaluation of models.
#   - **`EarlyStoppingCallback`**: A callback to stop training when a specified metric stops improving.
#
# ## Evaluation Metrics
#
# - **`sklearn.metrics`**: Provides functions to assess the performance of machine learning models.
#   - **`accuracy_score`**: Calculates the accuracy of predictions.
#   - **`precision_recall_fscore_support`**: Computes precision, recall, F1-score, and support.
#   - **`roc_curve`**: Generates the Receiver Operating Characteristic (ROC) curve.
#   - **`auc`**: Calculates the Area Under the Curve (AUC) for ROC.
#   - **`precision_recall_curve`**: Plots the precision-recall curve.
#   - **`average_precision_score`**: Computes the average precision score.
#   - **`classification_report`**: Builds a text report showing the main classification metrics.
#   - **`confusion_matrix`**: Generates a confusion matrix to evaluate classification accuracy.
#
# ## Visualization
#
# - **`matplotlib.pyplot as plt`**: A plotting library for creating static, animated, and interactive visualizations.
# - **`seaborn as sns`**: A data visualization library based on Matplotlib, offering a high-level interface for drawing attractive statistical graphics.
#
# ## Arabic Text Processing
#
# - **`arabic_reshaper`**: Reshapes Arabic text for proper display in environments that do not support Arabic script.
# - **`bidi.algorithm.get_display`**: Reorders bidirectional text for correct display, essential for languages like Arabic.
# - **`arabert.preprocess`**: Provides preprocessing functions tailored for Arabic text, enhancing compatibility with the AraBERT model.
# - **`pyarabic.araby`**: Offers utilities for Arabic text processing.
#   - **`strip_tashkeel`**: Removes diacritics from Arabic text.
#   - **`strip_tatweel`**: Eliminates elongation characters from Arabic text.
#
# ## Word Cloud Generation
#
# - **`wordcloud`**: Generates word clouds, which are visual representations of text data where the size of each word indicates its frequency or importance.
#
# ## Summary
#
# The imported libraries and modules encompass a wide range of functionalities, including data manipulation, machine learning, evaluation metrics, visualization, and specialized processing for Arabic text. This comprehensive set of tools facilitates the development and evaluation of models, particularly those focused on Arabic language processing.

# %%
import os
import pandas as pd
import numpy as np
import torch
from datasets import Dataset
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
    EarlyStoppingCallback
)
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns
import arabic_reshaper
from bidi.algorithm import get_display
import re
from collections import Counter
from wordcloud import WordCloud
import numpy as np
from sklearn.metrics import confusion_matrix
import arabert.preprocess
from pyarabic.araby import strip_tashkeel, strip_tatweel
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_curve, auc,
    precision_recall_curve, average_precision_score
)
import pandas as pd
import os
import torch
from arabic_reshaper import reshape
from bidi.algorithm import get_display

# %% [markdown]
# # ArabicTextPreprocessor Class:
#
# ## Overview
# The `ArabicTextPreprocessor` class provides a comprehensive pipeline for cleaning and preprocessing Arabic text, preparing it for natural language processing (NLP) tasks.
#
# ## Key Components
#
# ### Initialization
# - **`__init__`**:
#   - Initializes the AraBERT preprocessor with a specified model (default: `FacebookAI/xlm-roberta-base`).
#   - Compiles regex patterns for efficiency (e.g., URLs, HTML tags, emails).
#
# ### Text Cleaning Methods
# 1. **`normalize_arabic_characters`**:
#    - Unifies Arabic character variations (e.g., Alef, Ya, Ha).
# 2. **`remove_emojis`**:
#    - Removes emojis from text using the `emoji` library.
# 3. **`remove_diacritics`**:
#    - Strips Arabic diacritical marks (e.g., Tashkeel, Tatweel) using `pyarabic`.
# 4. **`basic_clean`**:
#    - Performs the following:
#      - Removes irrelevant lines (e.g., containing "مقال").
#      - Normalizes characters.
#      - Removes emojis, diacritics, HTML tags, URLs, email addresses, and punctuation.
#      - Strips extra whitespace.
#
# ### Preprocessing Pipelines
# 1. **`preprocess`**:
#    - Executes the full cleaning pipeline, including AraBERT-specific preprocessing.
# 2. **`advanced_preprocessing`**:
#    - Offers additional flexibility with options to:
#      - Normalize characters.
#      - Remove diacritics.
#      - Remove punctuation.
#
# ## Benefits
# - **Comprehensive Cleaning**: Handles a wide range of Arabic-specific text challenges.
# - **Customizable**: Provides options for advanced, configurable preprocessing.
# - **AraBERT Integration**: Ensures compatibility with Arabic pre-trained models.

# %%
import re
import unicodedata
import emoji
from pyarabic.araby import strip_tashkeel, strip_tatweel
import arabert.preprocess

class ArabicTextPreprocessor:
    def __init__(self, model_name="FacebookAI/xlm-roberta-base"):
        """
        Initialize the Arabic text preprocessor

        Args:
            model_name (str): Name of the AraBERT model to use for preprocessing
        """
        self.arabert_prep = arabert.preprocess.ArabertPreprocessor(
            model_name=model_name
        )

        # Compile regex patterns for efficiency
        self.url_pattern = re.compile(r'http\S+|www\.\S+')
        self.html_tag_pattern = re.compile(r'<[^<]+?>')
        self.email_pattern = re.compile(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b')

        # Define additional cleaning patterns
        self.punctuation_pattern = re.compile(r'[^\w\s\u0600-\u06FF]')

    def normalize_arabic_characters(self, text):
        """
        Normalize Arabic characters to improve consistency

        Args:
            text (str): Input text

        Returns:
            str: Normalized text
        """
        # Normalize Alef variations
        text = text.replace('أ', 'ا')
        text = text.replace('إ', 'ا')
        text = text.replace('آ', 'ا')

        # Normalize Ya variations
        text = text.replace('ى', 'ي')

        # Normalize Ha variations
        text = text.replace('ة', 'ه')

        return text

    def remove_emojis(self, text):
        """
        Remove emojis from text

        Args:
            text (str): Input text

        Returns:
            str: Text without emojis
        """
        return emoji.replace_emoji(text, replace='')

    def remove_diacritics(self, text):
        """
        Remove Arabic diacritical marks

        Args:
            text (str): Input text

        Returns:
            str: Text without diacritics
        """
        # Remove tashkeel and tatweel
        text = strip_tashkeel(text)
        text = strip_tatweel(text)

        return text

    def basic_clean(self, text):
        """
        Perform basic text cleaning

        Args:
            text (str): Input text

        Returns:
            str: Cleaned text
        """
        if not isinstance(text, str):
            return ""

        # Split text into lines
        lines = text.split('\n')

        # Remove first line if it contains 'مقال' and has 2-3 words
        if lines and len(lines[0].split()) <= 3 and 'مقال' in lines[0]:
            lines = lines[1:]

        # Rejoin the text
        text = '\n'.join(lines)

        # Normalize characters
        text = self.normalize_arabic_characters(text)

        # Remove emojis
        text = self.remove_emojis(text)

        # Remove diacritics
        text = self.remove_diacritics(text)

        # Remove HTML tags
        text = self.html_tag_pattern.sub('', text)

        # Remove URLs
        text = self.url_pattern.sub('', text)

        # Remove email addresses
        text = self.email_pattern.sub('', text)

        # Remove punctuation (except Arabic characters and whitespace)
        text = self.punctuation_pattern.sub('', text)

        # Remove asterisks and other special characters
        text = text.replace('*', '')

        # Remove extra whitespace
        text = ' '.join(text.split())

        return text

    def preprocess(self, text):
        """
        Full preprocessing pipeline

        Args:
            text (str): Input text

        Returns:
            str: Preprocessed text
        """
        # Basic cleaning
        text = self.basic_clean(text)

        # AraBERT preprocessing
        text = self.arabert_prep.preprocess(text)

        return text

    def advanced_preprocessing(self, text,
                                normalize_chars=True,
                                remove_diacritics=True,
                                remove_punctuation=True):
        """
        Advanced preprocessing with configurable options

        Args:
            text (str): Input text
            normalize_chars (bool): Normalize Arabic characters
            remove_diacritics (bool): Remove diacritical marks
            remove_punctuation (bool): Remove punctuation

        Returns:
            str: Advanced preprocessed text
        """
        # Basic cleaning
        text = self.basic_clean(text)

        # Optional character normalization
        if normalize_chars:
            text = self.normalize_arabic_characters(text)

        # Optional diacritics removal
        if remove_diacritics:
            text = self.remove_diacritics(text)

        # Optional punctuation removal
        if remove_punctuation:
            text = self.punctuation_pattern.sub('', text)

        # AraBERT preprocessing
        text = self.arabert_prep.preprocess(text)

        return text

# %% [markdown]
# # Function: `load_and_preprocess_data`
#
# ## Purpose
# This function loads Arabic text data from a specified directory, preprocesses it using the `ArabicTextPreprocessor` class, and provides detailed analytics on the preprocessing steps.
#
# ## Parameters
# - **`split_dir`**: Path to the directory containing text files.
# - **`metadata_file`**: Path to an Excel file with metadata (currently read but not utilized in the function).
#
# ## Workflow
# 1. **Initialization**:
#    - Instantiate the `ArabicTextPreprocessor` for text preprocessing.
#    - Read the metadata Excel file into a DataFrame (though it's not used further in the function).
#
# 2. **Data Processing**:
#    - Initialize a dictionary to store text data, preprocessed text, labels, text lengths, preprocessed text lengths, and filenames.
#    - Iterate over each `.txt` file in the specified directory:
#      - Read the file content.
#      - Preprocess the text using the `preprocess` method.
#      - Determine the label based on the filename (`1` if 'generated' is in the filename; otherwise, `0`).
#      - Calculate the word count for both original and preprocessed text.
#      - Store the original text, preprocessed text, label, word counts, and filename in the dictionary.
#
# 3. **DataFrame Creation**:
#    - Convert the dictionary into a Pandas DataFrame for structured data handling.
#
# 4. **Preprocessing Statistics**:
#    - Compute and store various statistics:
#      - Total number of files processed.
#      - Average word count of original texts.
#      - Average word count of preprocessed texts.
#      - Average number of characters removed during preprocessing.
#      - Count of files where the first line was removed (if it contained 'مقال').
#
# ## Returns
# - **`df`**: A DataFrame containing the original text, preprocessed text, labels, word counts, and filenames.
# - **`preprocessing_stats`**: A dictionary with statistics summarizing the preprocessing outcomes.

# %%
def load_and_preprocess_data(split_dir, metadata_file):
    """Load and preprocess the data with detailed analytics"""
    preprocessor = ArabicTextPreprocessor()

    # Read metadata
    df = pd.read_excel(metadata_file)

    # Process files
    data = {
        'text': [],
        'preprocessed_text': [],
        'label': [],
        'length': [],
        'preprocessed_length': [],
        'filename': []
    }

    for filename in os.listdir(split_dir):
        if filename.endswith('.txt'):
            file_path = os.path.join(split_dir, filename)
            with open(file_path, 'r', encoding='utf-8') as f:
                text = f.read().strip()

            # Preprocess text
            preprocessed_text = preprocessor.preprocess(text)

            # Store data
            data['text'].append(text)
            data['preprocessed_text'].append(preprocessed_text)
            data['label'].append(1 if 'generated' in filename else 0)
            data['length'].append(len(text.split()))
            data['preprocessed_length'].append(len(preprocessed_text.split()))
            data['filename'].append(filename)

    df = pd.DataFrame(data)

    # Save preprocessing stats
    preprocessing_stats = {
        'Total Files': len(df),
        'Average Original Length': df['length'].mean(),
        'Average Preprocessed Length': df['preprocessed_length'].mean(),
        'Average Characters Removed': (df['text'].str.len() - df['preprocessed_text'].str.len()).mean(),
        'Files with First Line Removed': sum(df['text'].str.split('\n').str[0].str.contains('مقال', na=False))
    }

    return df, preprocessing_stats

# %% [markdown]
# # Explanation: Directory Setup
#
# ## Purpose
# This snippet sets up directories for handling datasets and storing results for an Arabic text classification task.
#
# ## Code Breakdown
# 1. **Define Base Directory**:
#    - `base_dir = 'dataset/splits'`
#    - Specifies the location of the dataset, particularly in a `splits` subdirectory within a `dataset` folder.
#
# 2. **Define Output Directory**:
#    - `output_dir = 'arabic_classification_results'`
#    - Specifies the directory where results of the classification task (e.g., preprocessed data, metrics) will be saved.
#
# 3. **Create Output Directory**:
#    - `os.makedirs(output_dir, exist_ok=True)`
#    - Ensures the output directory exists.
#    - If the directory does not already exist, it will be created.
#    - The `exist_ok=True` flag prevents errors if the directory already exists.
#
#
#
# ## Benefits
# - Organized structure for dataset handling and result storage.
# - Prevents errors from missing or duplicate directories.

# %%
# Set up directories
base_dir = 'dataset/splits'
output_dir = 'arabic_classification_results'
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# # Explanation: Loading and Preprocessing Data
#
# ## Purpose
# This code snippet loads text data from training, validation, and test directories, preprocesses it, and provides preprocessing statistics.
#
# ## Workflow
#
# 1. **Print Status**:
#    - `print("Loading and preprocessing data...")`
#    - Displays a message to indicate the start of the data loading and preprocessing process.
#
# 2. **Load and Preprocess Data**:
#    - **`load_and_preprocess_data`**:
#      - Processes files in the specified directories (`train`, `val`, `test`) using the `ArabicTextPreprocessor` class.
#      - Cleans and prepares text data for model training, validation, and testing.
#
#    - **Arguments**:
#      - `os.path.join(base_dir, 'train')`: Path to the training data directory.
#      - `'dataset/combined_dataset_metadata.xlsx'`: Path to the metadata file for additional information.
#      - Similarly, validation (`val`) and testing (`test`) directories are specified.
#
# 3. **Outputs**:
#    - **`train_df`, `val_df`, `test_df`**:
#      - Pandas DataFrames containing original and preprocessed text, labels, text lengths, and filenames for the respective datasets.
#    - **`train_prep_stats`, `val_prep_stats`, `test_prep_stats`**:
#      - Dictionaries with preprocessing statistics (e.g., average lengths, number of cleaned files).

# %%
# Load and preprocess data
print("Loading and preprocessing data...")

train_df, train_prep_stats = load_and_preprocess_data(
    os.path.join(base_dir, 'train'),
    'dataset/combined_dataset_metadata.xlsx'
)
val_df, val_prep_stats = load_and_preprocess_data(
    os.path.join(base_dir, 'val'),
    'dataset/combined_dataset_metadata.xlsx'
)
test_df, test_prep_stats = load_and_preprocess_data(
    os.path.join(base_dir, 'test'),
    'dataset/combined_dataset_metadata.xlsx'
)
# Out:
# WARNING:root:Model provided is not in the accepted model list. Preprocessor will default to a base Arabic preprocessor
# Loading and preprocessing data...
# WARNING:root:Model provided is not in the accepted model list. Preprocessor will default to a base Arabic preprocessor
# WARNING:root:Model provided is not in the accepted model list. Preprocessor will default to a base Arabic preprocessor

# %% [markdown]
# #**BiLSTM,Attention,Retention Mechanisms introduction**
# ##Models Performance Proposed Enhancements:
# For more probable model enhancement,BiLSTM,Attention,Retention Mechanisms are introduced to arabic language models:
# BiLSTM (Bidirectional Long Short-Term Memory):
#
# 1. BiLSTM (Bidirectional Long Short-Term Memory):
# extends LSTMs by processing input sequences in both forward and backward directions using two separate hidden layers. The outputs are then concatenated, capturing both past and future contexts.The memory cells of LSTM retain important information, while the bidirectional setup ensures that dependencies between distant words.
# 2. Attention Mechanism:
# calculates a weighted relevance score between every input token and its target representation, focusing on the most contextually important tokens for generating outputs.This is implemented as a weighted sum of encoder hidden states in sequence-to-sequence models. In Arabic, where sentence meanings rely heavily on word context and semantics, attention ensures the model focuses on significant words while ignoring less relevant parts.
# 3. Retention mechanisms:
# Extends recurrent networks by preserving long-term dependencies over extended sequences. They involve enhanced gating systems to reduce the decay of information over time.It mitigates the loss of information in longer Arabic texts, which often feature nested clauses and complex structures.

# %% [markdown]
# ###Herein after, the process of enhancment and layers introduction will be in steps as follows:
# 1. Analyze data for data preparation,importing and preprocessing.
# 2. Tokenization
# 3. Compatible HuggingFace datasets conversion
# 4. Training:
#    a.Defining model architecture.
#    b.Model initialization
#    c. Defining model judgement metrics
#    d.trainng arguments definition
#    e.training
# ###Above mentioned steps will be applied on these models
# ####Selected language models for enhancement are:
# 1. aubmindlab/bert-base-arabertv02
# 2. aubmindlab/bert-large-arabertv2
# 3. asafaya/bert-base-arabic
# 4. FacebookAI/xlm-roberta-base",
# 5. araelectra-base-discriminator"

# %% [markdown]
# ###**1-aubmindlab/bert-base-arabertv02 Model Enhancement**

# %%
# Analyze datasets
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as scipy_stats  # Rename to avoid conflict
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from collections import Counter
from wordcloud import WordCloud

def analyze_data(df, output_dir):
    """
    Generate detailed analytics about the dataset with both original and enhanced analyses

    Args:
        df (pd.DataFrame): DataFrame containing the dataset
        output_dir (str): Directory to save the results

    Returns:
        dict: A dictionary with basic statistics
    """
    os.makedirs(output_dir, exist_ok=True)

    # 1. Basic statistics (Preserved from original implementation)
    dataset_stats = {
        'Total Samples': len(df),
        'Real Articles': sum(df['label'] == 0),
        'Generated Articles': sum(df['label'] == 1),
        'Average Original Length': df['length'].mean(),
        'Average Preprocessed Length': df['preprocessed_length'].mean(),
        'Max Length': df['length'].max(),
        'Min Length': df['length'].min(),
        'Median Length': df['length'].median()
    }

    # Save basic stats
    pd.DataFrame([dataset_stats]).to_csv(os.path.join(output_dir, 'basic_stats.csv'))

    # 2. Length distribution plot (Original implementation)
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='label', y='length', data=df)
    plt.title('Article Length Distribution by Class')
    plt.xlabel('Class (0: Real, 1: Generated)')
    plt.ylabel('Word Count')
    plt.savefig(os.path.join(output_dir, 'length_distribution.png'))
    plt.close()

    # 3. Length histogram (Original implementation)
    plt.figure(figsize=(12, 6))
    plt.hist(df['length'], bins=50, alpha=0.5, label='Original')
    plt.hist(df['preprocessed_length'], bins=50, alpha=0.5, label='Preprocessed')
    plt.title('Article Length Distribution')
    plt.xlabel('Word Count')
    plt.ylabel('Frequency')
    plt.legend()
    plt.savefig(os.path.join(output_dir, 'length_histogram.png'))
    plt.close()

    # 4. Enhanced Length Distribution Plots (New addition)
    def plot_length_distribution(df, column, title, filename):
        plt.figure(figsize=(15, 10))
        sns.kdeplot(data=df, x=column, hue='label', fill=True, common_norm=False, palette="crest", alpha=0.5)
        plt.title(title)
        plt.xlabel('Word Count')
        plt.ylabel('Density')
        plt.savefig(os.path.join(output_dir, filename))
        plt.close()

    plot_length_distribution(df, 'length', 'Article Length Distribution by Class (KDE)', 'length_distribution_kde.png')
    plot_length_distribution(df, 'preprocessed_length', 'Preprocessed Article Length Distribution by Class (KDE)', 'preprocessed_length_distribution_kde.png')

    # 5. Box Plot with Outliers (New addition)
    plt.figure(figsize=(15, 10))
    sns.boxplot(x='label', y='length', data=df, showfliers=True)
    sns.stripplot(x='label', y='length', data=df, size=4, color='.3', linewidth=0)
    plt.title('Article Length Distribution by Class with Outliers')
    plt.xlabel('Class (0: Real, 1: Generated)')
    plt.ylabel('Word Count')
    plt.savefig(os.path.join(output_dir, 'length_distribution_boxplot.png'))
    plt.close()

    # 6. Statistical Tests (New addition)
    real_lengths = df[df['label'] == 0]['length']
    gen_lengths = df[df['label'] == 1]['length']

    # Perform t-test
    try:
        t_stat, p_value = scipy_stats.ttest_ind(real_lengths, gen_lengths, equal_var=False)
        dataset_stats['T-test Statistic'] = t_stat
        dataset_stats['T-test P-value'] = p_value
    except Exception as e:
        print(f"T-test calculation error: {e}")
        dataset_stats['T-test Statistic'] = None
        dataset_stats['T-test P-value'] = None

    # 7. Word Frequency Analysis (New addition)
    def get_top_words(texts, n=20):
        words = ' '.join(texts).split()
        word_counts = Counter(words)
        return pd.DataFrame(word_counts.most_common(n), columns=['Word', 'Count'])

    # Top words for each class
    top_words_real = get_top_words(df[df['label'] == 0]['text'])
    top_words_gen = get_top_words(df[df['label'] == 1]['text'])

    top_words_real.to_csv(os.path.join(output_dir, 'top_words_real.csv'), index=False)
    top_words_gen.to_csv(os.path.join(output_dir, 'top_words_generated.csv'), index=False)

    # 8. Correlation Heatmap (New addition)
    correlation = df[['length', 'preprocessed_length', 'label']].corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation, annot=True, cmap='coolwarm')
    plt.title('Correlation Between Features')
    plt.savefig(os.path.join(output_dir, 'correlation_heatmap.png'))
    plt.close()

    # Additional error handling and logging
    print("Dataset analysis completed successfully.")

    return dataset_stats

# Usage remains the same
# Analyze datasets
print("Analyzing datasets...")
train_stats = analyze_data(train_df, os.path.join(output_dir, 'train_analytics'))
val_stats = analyze_data(val_df, os.path.join(output_dir, 'val_analytics'))
test_stats = analyze_data(test_df, os.path.join(output_dir, 'test_analytics'))
# Out:
# Analyzing datasets...
# Dataset analysis completed successfully.
# Dataset analysis completed successfully.
# Dataset analysis completed successfully.
# Analyzing datasets...
# Dataset analysis completed successfully.
# Dataset analysis completed successfully.

# %%
# Convert to HuggingFace datasets
train_dataset = Dataset.from_pandas(train_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
val_dataset = Dataset.from_pandas(val_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
test_dataset = Dataset.from_pandas(test_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
# Tokenize datasets
print("Tokenizing datasets...")
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
# Out:
# Parameter 'function'=<function tokenize_function at 0x7a2c3ca27400> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# WARNING:datasets.fingerprint:Parameter 'function'=<function tokenize_function at 0x7a2c3ca27400> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# Tokenizing datasets...
# Map:   0%|          | 0/6515 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1397 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1397 [00:00<?, ? examples/s]

# %%
#new for "aubmindlab/bert-base-arabertv2"
# Initialize tokenizer
print("Initializing tokenizer and model...")
tokenizer = AutoTokenizer.from_pretrained("aubmindlab/bert-base-arabertv02")
# Out:
# Initializing tokenizer and model...

# %%
import os
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from transformers import AutoTokenizer, AutoModel, Trainer, TrainingArguments, EarlyStoppingCallback
from arabert.preprocess import ArabertPreprocessor
from sklearn.metrics import (
    precision_recall_fscore_support,
    accuracy_score,
    roc_curve,
    auc,
    confusion_matrix
)
import matplotlib.pyplot as plt
import seaborn as sns

# Preprocessor for AraBERT
arabert_prep = ArabertPreprocessor(model_name="aubmindlab/bert-base-arabertv2")

# Define the Arabic Text Classifier
class ArabicTextClassifier(nn.Module):
    def __init__(self, pretrained_model_name="aubmindlab/bert-base-arabertv2",
                 hidden_size=256, num_classes=2):
        super(ArabicTextClassifier, self).__init__()

        # Pretrained AraBERTv2 model
        self.backbone = AutoModel.from_pretrained(pretrained_model_name)

        # Freeze backbone layers (optional)
        for param in self.backbone.parameters():
            param.requires_grad = False

        # BiLSTM Layer
        self.bilstm = nn.LSTM(
            input_size=self.backbone.config.hidden_size,
            hidden_size=hidden_size,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        # Retention Mechanism (custom layer)
        self.retention = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size, hidden_size * 2)
        )

        # Attention Mechanism
        self.attention = nn.Linear(hidden_size * 2, 1)

        # Classification Head
        self.classifier = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size, num_classes)
        )

        # Loss function
        self.loss_fn = nn.CrossEntropyLoss()

    def forward(self, input_ids, attention_mask, labels=None):
        # Get embeddings from AraBERT
        outputs = self.backbone(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        # Extract last hidden state
        sequence_output = outputs.last_hidden_state

        # Prepare sequence lengths for packed sequence
        lengths = attention_mask.sum(dim=1)

        # Pack sequence for BiLSTM
        packed_sequence = pack_padded_sequence(
            sequence_output,
            lengths.cpu(),
            batch_first=True,
            enforce_sorted=False
        )

        # BiLSTM processing
        packed_output, _ = self.bilstm(packed_sequence)

        # Unpack sequence
        lstm_output, _ = pad_packed_sequence(packed_output, batch_first=True)

        # Apply retention mechanism
        lstm_output = self.retention(lstm_output)

        # Attention mechanism
        attention_weights = torch.softmax(
            self.attention(lstm_output).squeeze(-1),
            dim=1
        )

        # Weighted sum of BiLSTM outputs
        context_vector = torch.bmm(
            attention_weights.unsqueeze(1),
            lstm_output
        ).squeeze(1)

        # Classification
        logits = self.classifier(context_vector)

        # Compute loss if labels are provided
        loss = None
        if labels is not None:
            loss = self.loss_fn(logits, labels)

        return {
            'loss': loss,
            'logits': logits
        }

# Initialize model
model = ArabicTextClassifier(
    pretrained_model_name="aubmindlab/bert-base-arabertv2",
    hidden_size=256,
    num_classes=2
)

# Define tokenizer
tokenizer = AutoTokenizer.from_pretrained("aubmindlab/bert-base-arabertv2")

# Preprocess and tokenize function
def tokenize_function(examples):
    # Preprocess using ArabertPreprocessor
    examples['text'] = [arabert_prep.preprocess(text) for text in examples['text']]
    return tokenizer(examples['text'], padding="max_length", truncation=True)

# Define compute_metrics
def compute_metrics(pred):
    """Compute metrics for evaluation"""
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    # Precision, Recall, F1-Score
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')

    # Accuracy
    acc = accuracy_score(labels, preds)

    # Calculate ROC curve and AUC
    probs = torch.nn.functional.softmax(torch.tensor(pred.predictions), dim=-1)[:, 1].numpy()
    fpr, tpr, _ = roc_curve(labels, probs)
    roc_auc = auc(fpr, tpr)

    # Save ROC curve
    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.savefig('roc_curve.png')
    plt.close()

    # Confusion Matrix
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig('confusion_matrix.png')
    plt.close()

    # Return computed metrics
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall,
        'roc_auc': roc_auc
    }

# Training arguments
output_dir = "./model_output"
training_args = TrainingArguments(
    output_dir=output_dir,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    lr_scheduler_type="linear",
    warmup_ratio=0.1,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=10,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    save_total_limit=2,
    logging_dir=os.path.join(output_dir, 'logs'),
    logging_steps=10,
    report_to="tensorboard",
    gradient_accumulation_steps=1,
    max_grad_norm=1.0
)

# Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(
            early_stopping_patience=2,
            early_stopping_threshold=0.01
        )
    ]
)

# Train model
print("Training model...")
trainer.train()
# Out:
# [2024-12-24 09:38:22,819 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.
# Training model...
#     <div>
#
#       <progress value='93' max='2040' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  93/2040 01:38 < 34:57, 0.93 it/s, Epoch 0.45/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>

# %% [markdown]
# ###**2-aubmindlab/bert-large-arabertv2 Model Enhancement**

# %%
# Preprocessor for AraBERT Large
arabert_prep = ArabertPreprocessor(model_name="aubmindlab/bert-large-arabertv2")
# Out:
# [2024-11-26 17:24:40,281 - farasapy_logger - WARNING]: Be careful with large lines as they may break on interactive mode. You may switch to Standalone mode for such cases.

# %%
# Define the Arabic Text Classifier
class ArabicTextClassifier(nn.Module):
    def __init__(self, pretrained_model_name="aubmindlab/bert-large-arabertv2",
                 hidden_size=256, num_classes=2):
        super(ArabicTextClassifier, self).__init__()

        # Pretrained AraBERTv2 model
        self.backbone = AutoModel.from_pretrained(pretrained_model_name)

        # Freeze backbone layers (optional)
        for param in self.backbone.parameters():
            param.requires_grad = False

        # BiLSTM Layer
        self.bilstm = nn.LSTM(
            input_size=self.backbone.config.hidden_size,
            hidden_size=hidden_size,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        # Retention Mechanism (custom layer)
        self.retention = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size, hidden_size * 2)
        )

        # Attention Mechanism
        self.attention = nn.Linear(hidden_size * 2, 1)

        # Classification Head
        self.classifier = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size, num_classes)
        )

        # Loss function
        self.loss_fn = nn.CrossEntropyLoss()

    def forward(self, input_ids, attention_mask, labels=None):
        # Get embeddings from AraBERT
        outputs = self.backbone(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        # Extract last hidden state
        sequence_output = outputs.last_hidden_state

        # Prepare sequence lengths for packed sequence
        lengths = attention_mask.sum(dim=1)

        # Pack sequence for BiLSTM
        packed_sequence = pack_padded_sequence(
            sequence_output,
            lengths.cpu(),
            batch_first=True,
            enforce_sorted=False
        )

        # BiLSTM processing
        packed_output, _ = self.bilstm(packed_sequence)

        # Unpack sequence
        lstm_output, _ = pad_packed_sequence(packed_output, batch_first=True)

        # Apply retention mechanism
        lstm_output = self.retention(lstm_output)

        # Attention mechanism
        attention_weights = torch.softmax(
            self.attention(lstm_output).squeeze(-1),
            dim=1
        )

        # Weighted sum of BiLSTM outputs
        context_vector = torch.bmm(
            attention_weights.unsqueeze(1),
            lstm_output
        ).squeeze(1)

        # Classification
        logits = self.classifier(context_vector)

        # Compute loss if labels are provided
        loss = None
        if labels is not None:
            loss = self.loss_fn(logits, labels)

        return {
            'loss': loss,
            'logits': logits
        }

# Initialize model
model = ArabicTextClassifier(
    pretrained_model_name="aubmindlab/bert-large-arabertv2",
    hidden_size=256,
    num_classes=2
)
# Out:
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.48G [00:00<?, ?B/s]

# %%
# Training arguments
output_dir = "./model_output"
training_args = TrainingArguments(
    output_dir=output_dir,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    lr_scheduler_type="linear",
    warmup_ratio=0.1,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=10,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    save_total_limit=2,
    logging_dir=os.path.join(output_dir, 'logs'),
    logging_steps=10,
    report_to="tensorboard",
    gradient_accumulation_steps=1,
    max_grad_norm=1.0
)

# Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(
            early_stopping_patience=2,
            early_stopping_threshold=0.01
        )
    ]
)

# %%
# Train model
print("Training model...")
trainer.train()
# Out:
# Training model...
#     <div>
#
#       <progress value='463' max='2040' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 463/2040 28:59 < 1:39:08, 0.27 it/s, Epoch 2.26/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Roc Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.606600</td>
#       <td>0.563754</td>
#       <td>0.810308</td>
#       <td>0.824619</td>
#       <td>0.721065</td>
#       <td>0.962906</td>
#       <td>0.953020</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.148900</td>
#       <td>0.328833</td>
#       <td>0.851825</td>
#       <td>0.861908</td>
#       <td>0.758216</td>
#       <td>0.998454</td>
#       <td>0.988511</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# ###**3-asafaya/bert-base-arabic**

# %%
# new for "asafaya/bert-base-arabic"
print("Initializing tokenizer and model...")
tokenizer = AutoTokenizer.from_pretrained("asafaya/bert-base-arabic")
# Out:
# Initializing tokenizer and model...
# tokenizer_config.json:   0%|          | 0.00/62.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/334k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def tokenize_function(examples):
    return tokenizer(
        examples['text'],
        padding="max_length",
        truncation=True,
        max_length=512
    )

# %%
# Convert to HuggingFace datasets
train_dataset = Dataset.from_pandas(train_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
val_dataset = Dataset.from_pandas(val_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
test_dataset = Dataset.from_pandas(test_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))

# %%
# Tokenize datasets
print("Tokenizing datasets...")
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
# Out:
# Tokenizing datasets...
# Map:   0%|          | 0/6515 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1397 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1397 [00:00<?, ? examples/s]

# %%
import os
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from transformers import AutoModel, Trainer, TrainingArguments, EarlyStoppingCallback
from sklearn.metrics import (
    precision_recall_fscore_support,
    accuracy_score,
    roc_curve,
    auc,
    confusion_matrix
)
import matplotlib.pyplot as plt
import seaborn as sns

# Define the Arabic Text Classifier
class ArabicTextClassifier(nn.Module):
    def __init__(self, pretrained_model_name="asafaya/bert-base-arabic",
                 hidden_size=256, num_classes=2):
        super(ArabicTextClassifier, self).__init__()

        # Pretrained Bert-base Arabic model
        self.backbone = AutoModel.from_pretrained(pretrained_model_name)

        # Freeze backbone layers (optional)
        for param in self.backbone.parameters():
            param.requires_grad = False

        # BiLSTM Layer
        self.bilstm = nn.LSTM(
            input_size=self.backbone.config.hidden_size,
            hidden_size=hidden_size,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        # Retention Mechanism (custom layer)
        self.retention = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size, hidden_size * 2)
        )

        # Attention Mechanism
        self.attention = nn.Linear(hidden_size * 2, 1)

        # Classification Head
        self.classifier = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size, num_classes)
        )

        # Loss function
        self.loss_fn = nn.CrossEntropyLoss()

    def forward(self, input_ids, attention_mask, labels=None):
        # Get embeddings from Bert-base Arabic
        outputs = self.backbone(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        # Extract last hidden state
        sequence_output = outputs.last_hidden_state

        # Prepare sequence lengths for packed sequence
        lengths = attention_mask.sum(dim=1)

        # Pack sequence for BiLSTM
        packed_sequence = pack_padded_sequence(
            sequence_output,
            lengths.cpu(),
            batch_first=True,
            enforce_sorted=False
        )

        # BiLSTM processing
        packed_output, _ = self.bilstm(packed_sequence)

        # Unpack sequence
        lstm_output, _ = pad_packed_sequence(packed_output, batch_first=True)

        # Apply retention mechanism
        lstm_output = self.retention(lstm_output)

        # Attention mechanism
        attention_weights = torch.softmax(
            self.attention(lstm_output).squeeze(-1),
            dim=1
        )

        # Weighted sum of BiLSTM outputs
        context_vector = torch.bmm(
            attention_weights.unsqueeze(1),
            lstm_output
        ).squeeze(1)

        # Classification
        logits = self.classifier(context_vector)

        # Compute loss if labels are provided
        loss = None
        if labels is not None:
            loss = self.loss_fn(logits, labels)

        return {
            'loss': loss,
            'logits': logits
        }

# Initialize model
model = ArabicTextClassifier(
    pretrained_model_name="asafaya/bert-base-arabic",
    hidden_size=256,
    num_classes=2
)

# Define compute_metrics
def compute_metrics(pred):
    """Compute metrics for evaluation"""
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    # Precision, Recall, F1-Score
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')

    # Accuracy
    acc = accuracy_score(labels, preds)

    # Calculate ROC curve and AUC
    probs = torch.nn.functional.softmax(torch.tensor(pred.predictions), dim=-1)[:, 1].numpy()
    fpr, tpr, _ = roc_curve(labels, probs)
    roc_auc = auc(fpr, tpr)

    # Save ROC curve
    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.savefig('roc_curve.png')
    plt.close()

    # Confusion Matrix
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig('confusion_matrix.png')
    plt.close()

    # Return computed metrics
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall,
        'roc_auc': roc_auc
    }

# Training arguments
output_dir = "./model_output"
training_args = TrainingArguments(
    output_dir=output_dir,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    lr_scheduler_type="linear",
    warmup_ratio=0.1,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=10,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    save_total_limit=2,
    logging_dir=os.path.join(output_dir, 'logs'),
    logging_steps=10,
    report_to="tensorboard",
    gradient_accumulation_steps=1,
    max_grad_norm=1.0
)

# Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(
            early_stopping_patience=2,
            early_stopping_threshold=0.01
        )
    ]
)

# Train model
print("Training model...")
trainer.train()
# Out:
# Training model...
#     <div>
#
#       <progress value='816' max='2040' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 816/2040 17:34 < 26:25, 0.77 it/s, Epoch 4/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Roc Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.304500</td>
#       <td>0.216834</td>
#       <td>0.964925</td>
#       <td>0.963406</td>
#       <td>0.932081</td>
#       <td>0.996909</td>
#       <td>0.998920</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.009300</td>
#       <td>0.013757</td>
#       <td>0.997137</td>
#       <td>0.996914</td>
#       <td>0.995378</td>
#       <td>0.998454</td>
#       <td>0.999868</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.002000</td>
#       <td>0.009374</td>
#       <td>0.997137</td>
#       <td>0.996914</td>
#       <td>0.995378</td>
#       <td>0.998454</td>
#       <td>0.999924</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.001800</td>
#       <td>0.017729</td>
#       <td>0.996421</td>
#       <td>0.996145</td>
#       <td>0.993846</td>
#       <td>0.998454</td>
#       <td>0.999920</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=816, training_loss=0.16479119910389486, metrics={'train_runtime': 1057.2585, 'train_samples_per_second': 61.622, 'train_steps_per_second': 1.93, 'total_flos': 0.0, 'train_loss': 0.16479119910389486, 'epoch': 4.0})

# %% [markdown]
# ###**4-aubmindlab/araelectra-base-discriminator**

# %%
# new for  "UBC-NLP/ARBERT"
print("Initializing tokenizer and model...")
tokenizer = AutoTokenizer.from_pretrained( "aubmindlab/araelectra-base-discriminator")
# Out:
# Initializing tokenizer and model...
# tokenizer_config.json:   0%|          | 0.00/392 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/503 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/825k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.64M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
def tokenize_function(examples):
    return tokenizer(
        examples['text'],
        padding="max_length",
        truncation=True,
        max_length=512
    )

# %%
# Convert to HuggingFace datasets
train_dataset = Dataset.from_pandas(train_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
val_dataset = Dataset.from_pandas(val_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
test_dataset = Dataset.from_pandas(test_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))

# %%
# Tokenize datasets
print("Tokenizing datasets...")
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
# Out:
# Tokenizing datasets...
# Map:   0%|          | 0/6515 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1397 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1397 [00:00<?, ? examples/s]

# %%
import os
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from transformers import AutoModel, Trainer, TrainingArguments, EarlyStoppingCallback
from sklearn.metrics import (
    precision_recall_fscore_support,
    accuracy_score,
    roc_curve,
    auc,
    confusion_matrix
)
import matplotlib.pyplot as plt
import seaborn as sns

# Define the Arabic Text Classifier
class ArabicTextClassifier(nn.Module):
    def __init__(self, pretrained_model_name="aubmindlab/araelectra-base-discriminator",
                 hidden_size=256, num_classes=2):
        super(ArabicTextClassifier, self).__init__()

        # Pretrained Bert-base Arabic model
        self.backbone = AutoModel.from_pretrained(pretrained_model_name)

        # Freeze backbone layers (optional)
        for param in self.backbone.parameters():
            param.requires_grad = False

        # BiLSTM Layer
        self.bilstm = nn.LSTM(
            input_size=self.backbone.config.hidden_size,
            hidden_size=hidden_size,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        # Retention Mechanism (custom layer)
        self.retention = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size, hidden_size * 2)
        )

        # Attention Mechanism
        self.attention = nn.Linear(hidden_size * 2, 1)

        # Classification Head
        self.classifier = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size, num_classes)
        )

        # Loss function
        self.loss_fn = nn.CrossEntropyLoss()

    def forward(self, input_ids, attention_mask, labels=None):
        # Get embeddings from Bert-base Arabic
        outputs = self.backbone(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        # Extract last hidden state
        sequence_output = outputs.last_hidden_state

        # Prepare sequence lengths for packed sequence
        lengths = attention_mask.sum(dim=1)

        # Pack sequence for BiLSTM
        packed_sequence = pack_padded_sequence(
            sequence_output,
            lengths.cpu(),
            batch_first=True,
            enforce_sorted=False
        )

        # BiLSTM processing
        packed_output, _ = self.bilstm(packed_sequence)

        # Unpack sequence
        lstm_output, _ = pad_packed_sequence(packed_output, batch_first=True)

        # Apply retention mechanism
        lstm_output = self.retention(lstm_output)

        # Attention mechanism
        attention_weights = torch.softmax(
            self.attention(lstm_output).squeeze(-1),
            dim=1
        )

        # Weighted sum of BiLSTM outputs
        context_vector = torch.bmm(
            attention_weights.unsqueeze(1),
            lstm_output
        ).squeeze(1)

        # Classification
        logits = self.classifier(context_vector)

        # Compute loss if labels are provided
        loss = None
        if labels is not None:
            loss = self.loss_fn(logits, labels)

        return {
            'loss': loss,
            'logits': logits
        }

# Initialize model
model = ArabicTextClassifier(
    pretrained_model_name="aubmindlab/araelectra-base-discriminator",
    hidden_size=256,
    num_classes=2
)

# Define compute_metrics
def compute_metrics(pred):
    """Compute metrics for evaluation"""
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    # Precision, Recall, F1-Score
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')

    # Accuracy
    acc = accuracy_score(labels, preds)

    # Calculate ROC curve and AUC
    probs = torch.nn.functional.softmax(torch.tensor(pred.predictions), dim=-1)[:, 1].numpy()
    fpr, tpr, _ = roc_curve(labels, probs)
    roc_auc = auc(fpr, tpr)

    # Save ROC curve
    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.savefig('roc_curve.png')
    plt.close()

    # Confusion Matrix
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig('confusion_matrix.png')
    plt.close()

    # Return computed metrics
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall,
        'roc_auc': roc_auc
    }

# Training arguments
output_dir = "./model_output"
training_args = TrainingArguments(
    output_dir=output_dir,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    lr_scheduler_type="linear",
    warmup_ratio=0.1,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=10,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    save_total_limit=2,
    logging_dir=os.path.join(output_dir, 'logs'),
    logging_steps=10,
    report_to="tensorboard",
    gradient_accumulation_steps=1,
    max_grad_norm=1.0
)

# Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(
            early_stopping_patience=2,
            early_stopping_threshold=0.01
        )
    ]
)

# Train model
print("Training model...")
trainer.train()
# Out:
# model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# Training model...
#     <div>
#
#       <progress value='1632' max='2040' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1632/2040 43:52 < 10:58, 0.62 it/s, Epoch 8/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Roc Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.625600</td>
#       <td>0.594159</td>
#       <td>0.924123</td>
#       <td>0.923851</td>
#       <td>0.863087</td>
#       <td>0.993818</td>
#       <td>0.993875</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.002500</td>
#       <td>0.244841</td>
#       <td>0.940587</td>
#       <td>0.939724</td>
#       <td>0.886301</td>
#       <td>1.000000</td>
#       <td>0.998739</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001100</td>
#       <td>0.149622</td>
#       <td>0.951324</td>
#       <td>0.950073</td>
#       <td>0.904895</td>
#       <td>1.000000</td>
#       <td>0.999365</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.001700</td>
#       <td>0.131395</td>
#       <td>0.968504</td>
#       <td>0.967115</td>
#       <td>0.936324</td>
#       <td>1.000000</td>
#       <td>0.999624</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000400</td>
#       <td>0.167224</td>
#       <td>0.955619</td>
#       <td>0.954277</td>
#       <td>0.912553</td>
#       <td>1.000000</td>
#       <td>0.999633</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.007700</td>
#       <td>0.066993</td>
#       <td>0.987115</td>
#       <td>0.986280</td>
#       <td>0.972932</td>
#       <td>1.000000</td>
#       <td>0.999829</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000200</td>
#       <td>0.072759</td>
#       <td>0.981389</td>
#       <td>0.980303</td>
#       <td>0.961367</td>
#       <td>1.000000</td>
#       <td>0.999848</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.015100</td>
#       <td>0.073368</td>
#       <td>0.984968</td>
#       <td>0.984030</td>
#       <td>0.968563</td>
#       <td>1.000000</td>
#       <td>0.999856</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1632, training_loss=0.10732040979900037, metrics={'train_runtime': 2634.0397, 'train_samples_per_second': 24.734, 'train_steps_per_second': 0.774, 'total_flos': 0.0, 'train_loss': 0.10732040979900037, 'epoch': 8.0})

# %% [markdown]
# ###5-**FacebookAI/xlm-roberta-base**

# %%
# new for  "FacebookAI/xlm-roberta-base"
print("Initializing tokenizer and model...")
tokenizer = AutoTokenizer.from_pretrained( "FacebookAI/xlm-roberta-base")
# Out:
# Initializing tokenizer and model...
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]

# %%
def tokenize_function(examples):
    return tokenizer(
        examples['text'],
        padding="max_length",
        truncation=True,
        max_length=512
    )

# %%
# Convert to HuggingFace datasets
train_dataset = Dataset.from_pandas(train_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
val_dataset = Dataset.from_pandas(val_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))
test_dataset = Dataset.from_pandas(test_df[['preprocessed_text', 'label']].rename(columns={'preprocessed_text': 'text'}))

# %%
# Tokenize datasets
print("Tokenizing datasets...")
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)
# Out:
# Tokenizing datasets...
# Map:   0%|          | 0/6515 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1397 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1397 [00:00<?, ? examples/s]

# %%
import os
import torch
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
from transformers import AutoModel, Trainer, TrainingArguments, EarlyStoppingCallback
from sklearn.metrics import (
    precision_recall_fscore_support,
    accuracy_score,
    roc_curve,
    auc,
    confusion_matrix
)
import matplotlib.pyplot as plt
import seaborn as sns

# Define the Arabic Text Classifier
class ArabicTextClassifier(nn.Module):
    def __init__(self, pretrained_model_name="FacebookAI/xlm-roberta-base",
                 hidden_size=256, num_classes=2):
        super(ArabicTextClassifier, self).__init__()

        # Pretrained Bert-base Arabic model
        self.backbone = AutoModel.from_pretrained(pretrained_model_name)

        # Freeze backbone layers (optional)
        for param in self.backbone.parameters():
            param.requires_grad = False

        # BiLSTM Layer
        self.bilstm = nn.LSTM(
            input_size=self.backbone.config.hidden_size,
            hidden_size=hidden_size,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        # Retention Mechanism (custom layer)
        self.retention = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.1),
            nn.Linear(hidden_size, hidden_size * 2)
        )

        # Attention Mechanism
        self.attention = nn.Linear(hidden_size * 2, 1)

        # Classification Head
        self.classifier = nn.Sequential(
            nn.Linear(hidden_size * 2, hidden_size),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(hidden_size, num_classes)
        )

        # Loss function
        self.loss_fn = nn.CrossEntropyLoss()

    def forward(self, input_ids, attention_mask, labels=None):
        # Get embeddings from Bert-base Arabic
        outputs = self.backbone(
            input_ids=input_ids,
            attention_mask=attention_mask
        )

        # Extract last hidden state
        sequence_output = outputs.last_hidden_state

        # Prepare sequence lengths for packed sequence
        lengths = attention_mask.sum(dim=1)

        # Pack sequence for BiLSTM
        packed_sequence = pack_padded_sequence(
            sequence_output,
            lengths.cpu(),
            batch_first=True,
            enforce_sorted=False
        )

        # BiLSTM processing
        packed_output, _ = self.bilstm(packed_sequence)

        # Unpack sequence
        lstm_output, _ = pad_packed_sequence(packed_output, batch_first=True)

        # Apply retention mechanism
        lstm_output = self.retention(lstm_output)

        # Attention mechanism
        attention_weights = torch.softmax(
            self.attention(lstm_output).squeeze(-1),
            dim=1
        )

        # Weighted sum of BiLSTM outputs
        context_vector = torch.bmm(
            attention_weights.unsqueeze(1),
            lstm_output
        ).squeeze(1)

        # Classification
        logits = self.classifier(context_vector)

        # Compute loss if labels are provided
        loss = None
        if labels is not None:
            loss = self.loss_fn(logits, labels)

        return {
            'loss': loss,
            'logits': logits
        }

# Initialize model
model = ArabicTextClassifier(
    pretrained_model_name="FacebookAI/xlm-roberta-base",
    hidden_size=256,
    num_classes=2
)

# Define compute_metrics
def compute_metrics(pred):
    """Compute metrics for evaluation"""
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    # Precision, Recall, F1-Score
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='binary')

    # Accuracy
    acc = accuracy_score(labels, preds)

    # Calculate ROC curve and AUC
    probs = torch.nn.functional.softmax(torch.tensor(pred.predictions), dim=-1)[:, 1].numpy()
    fpr, tpr, _ = roc_curve(labels, probs)
    roc_auc = auc(fpr, tpr)

    # Save ROC curve
    plt.figure(figsize=(8, 8))
    plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic')
    plt.legend(loc="lower right")
    plt.savefig('roc_curve.png')
    plt.close()

    # Confusion Matrix
    cm = confusion_matrix(labels, preds)
    plt.figure(figsize=(8, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.savefig('confusion_matrix.png')
    plt.close()

    # Return computed metrics
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall,
        'roc_auc': roc_auc
    }

# Training arguments
output_dir = "./model_output"
training_args = TrainingArguments(
    output_dir=output_dir,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=2e-5,
    lr_scheduler_type="linear",
    warmup_ratio=0.1,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    num_train_epochs=10,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="f1",
    save_total_limit=2,
    logging_dir=os.path.join(output_dir, 'logs'),
    logging_steps=10,
    report_to="tensorboard",
    gradient_accumulation_steps=1,
    max_grad_norm=1.0
)

# Trainer setup
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    compute_metrics=compute_metrics,
    callbacks=[
        EarlyStoppingCallback(
            early_stopping_patience=2,
            early_stopping_threshold=0.01
        )
    ]
)

# Train model
print("Training model...")
trainer.train()
# Out:
# model.safetensors:   0%|          | 0.00/1.12G [00:00<?, ?B/s]
# Training model...
#     <div>
#
#       <progress value='816' max='2040' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 816/2040 18:55 < 28:27, 0.72 it/s, Epoch 4/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>Roc Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.671400</td>
#       <td>0.666307</td>
#       <td>0.536865</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.968494</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.150200</td>
#       <td>0.124070</td>
#       <td>0.981389</td>
#       <td>0.980153</td>
#       <td>0.968326</td>
#       <td>0.992272</td>
#       <td>0.996620</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.028900</td>
#       <td>0.147253</td>
#       <td>0.970651</td>
#       <td>0.969150</td>
#       <td>0.944282</td>
#       <td>0.995363</td>
#       <td>0.996437</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.017500</td>
#       <td>0.088758</td>
#       <td>0.981389</td>
#       <td>0.980153</td>
#       <td>0.968326</td>
#       <td>0.992272</td>
#       <td>0.998195</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=816, training_loss=0.28364921684431676, metrics={'train_runtime': 1137.9069, 'train_samples_per_second': 57.254, 'train_steps_per_second': 1.793, 'total_flos': 0.0, 'train_loss': 0.28364921684431676, 'epoch': 4.0})
